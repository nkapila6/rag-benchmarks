# %%
import os
os.chdir('..')

# %%
import torch

def get_best_device():
    if torch.cuda.is_available():
        print("Found CUDA GPU.")
    elif torch.backends.mps.is_available():
        print("Found Apple Silicon GPU.")
    else:
        print("No GPU found. Using 'cpu'.")

print(os.getcwd())
get_best_device()
# Out:
# /Users/nkapila6/Code/rag-benchmarks
# Found Apple Silicon GPU.

# %%
DATA_DIR = "data/nfcorpus"

# %%
DATA_DIR = os.path.abspath(os.path.join(os.path.dirname(__file__), '..', 'data'))
DATASETS = [
    d for d in os.listdir(DATA_DIR)
    if os.path.isdir(os.path.join(DATA_DIR, d)) and os.path.exists(os.path.join(DATA_DIR, d, 'corpus.jsonl'))
]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 DATA_DIR = os.path.abspath(os.path.join(os.path.dirname(__file__), '..', 'data'))
#       2 DATASETS = [
#       3     d for d in os.listdir(DATA_DIR)
#       4     if os.path.isdir(os.path.join(DATA_DIR, d)) and os.path.exists(os.path.join(DATA_DIR, d, 'corpus.jsonl'))
#       5 ]
#
# NameError: name '__file__' is not defined

# %%
# !python scripts/run_all_combinations.py
# Out:
# === Running experiments for dataset: fiqa ===
#
# --- TFIDF + no reranking (BASELINE) ---
# STEP: Parsed arguments:
# {
#   "dataset": "fiqa",
#   "data_dir": "./data",
#   "retriever": "tfidf",
#   "top_k": 100,
#   "dense_model": "sentence-transformers/all-MiniLM-L6-v2",
#   "hybrid_mode": "rrf",
#   "rrf_k": 60,
#   "w_sparse": 0.5,
#   "w_dense": 0.5,
#   "reranker": "none",
#   "bi_model": "sentence-transformers/all-mpnet-base-v2",
#   "cross_model": "cross-encoder/ms-marco-MiniLM-L6-v2",
#   "batch_size": 32,
#   "output": "/Users/nkapila6/Code/rag-benchmarks/outputs/fiqa_tfidf_none.json"
# }
# STEP: Loading BEIR dataset...
# STEP[data]: Preparing to load BEIR dataset 'fiqa' from base dir ./data
# STEP[data]: Loading BEIR data from ./data/fiqa (split='test')
# STEP: Parsed arguments:
# {
#   "dataset": "fiqa",
#   "data_dir": "./data",
#   "retriever": "tfidf",
#   "top_k": 100,
#   "dense_model": "sentence-transformers/all-MiniLM-L6-v2",
#   "hybrid_mode": "rrf",
#   "rrf_k": 60,
#   "w_sparse": 0.5,
#   "w_dense": 0.5,
#   "reranker": "none",
#   "bi_model": "sentence-transformers/all-mpnet-base-v2",
#   "cross_model": "cross-encoder/ms-marco-MiniLM-L6-v2",
#   "batch_size": 32,
#   "output": "/Users/nkapila6/Code/rag-benchmarks/outputs/fiqa_tfidf_none.json"
# }
# STEP: Loading BEIR dataset...
# STEP[data]: Preparing to load BEIR dataset 'fiqa' from base dir ./data
# STEP[data]: Loading BEIR data from ./data/fiqa (split='test')
# 100%|█████████████████████████████████| 57638/57638 [00:00<00:00, 292421.51it/s]
# 100%|█████████████████████████████████| 57638/57638 [00:00<00:00, 292421.51it/s]
# STEP[data]: Loaded corpus=57638 documents, queries=648, qrels=648
# STEP[data]: Loaded corpus=57638 documents, queries=648, qrels=648
# STEP[data]: Converted corpus to 57638 LangChain Documents
# STEP: Loaded dataset 'fiqa'. Corpus size: 57638, Queries: 648, Qrels: 648, Documents converted: 57638
# STEP: Building retriever...
# STEP[factory]: Building retriever kind='tfidf' (dense_model=sentence-transformers/all-MiniLM-L6-v2, rrf_k=60,
# STEP[data]: Converted corpus to 57638 LangChain Documents
# STEP: Loaded dataset 'fiqa'. Corpus size: 57638, Queries: 648, Qrels: 648, Documents converted: 57638
# STEP: Building retriever...
# STEP[factory]: Building retriever kind='tfidf' (dense_model=sentence-transformers/all-MiniLM-L6-v2, rrf_k=60,
# STEP: Retriever built.
# STEP: Building reranker...
# STEP[factory]: Building reranker kind='none' (bi_model=sentence-transformers/all-mpnet-base-v2, cross_model=cross-encoder/ms-marco-MiniLM-L6-v2, batch_size=32)
# STEP: Reranker built.
# STEP: Running evaluation over queries...
# STEP[eval]: Starting evaluation...
# STEP[eval]: Running pipeline over 648 queries with top_k=100
# STEP[eval]: Query id=8: retrieving candidates ...
# STEP: Retriever built.
# STEP: Building reranker...
# STEP[factory]: Building reranker kind='none' (bi_model=sentence-transformers/all-mpnet-base-v2, cross_model=cross-encoder/ms-marco-MiniLM-L6-v2, batch_size=32)
# STEP: Reranker built.
# STEP: Running evaluation over queries...
# STEP[eval]: Starting evaluation...
# STEP[eval]: Running pipeline over 648 queries with top_k=100
# STEP[eval]: Query id=8: retrieving candidates ...
# STEP[eval]: Query id=8: reranking 100 candidates ...
# STEP[eval]: Query id=8: got 100 results after rerank
# STEP[eval]: Query id=15: retrieving candidates ...
# STEP[eval]: Query id=15: reranking 100 candidates ...
# STEP[eval]: Query id=15: got 100 results after rerank
# STEP[eval]: Query id=18: retrieving candidates ...
# STEP[eval]: Query id=8: reranking 100 candidates ...
# STEP[eval]: Query id=8: got 100 results after rerank
# STEP[eval]: Query id=15: retrieving candidates ...
# STEP[eval]: Query id=15: reranking 100 candidates ...
# STEP[eval]: Query id=15: got 100 results after rerank
# STEP[eval]: Query id=18: retrieving candidates ...
# STEP[eval]: Query id=18: reranking 100 candidates ...
# STEP[eval]: Query id=18: got 100 results after rerank
# STEP[eval]: Query id=26: retrieving candidates ...
# STEP[eval]: Query id=26: reranking 100 candidates ...
# STEP[eval]: Query id=26: got 100 results after rerank
# STEP[eval]: Query id=34: retrieving candidates ...
# STEP[eval]: Query id=18: reranking 100 candidates ...
# STEP[eval]: Query id=18: got 100 results after rerank
# STEP[eval]: Query id=26: retrieving candidates ...
# STEP[eval]: Query id=26: reranking 100 candidates ...
# STEP[eval]: Query id=26: got 100 results after rerank
# STEP[eval]: Query id=34: retrieving candidates ...
# STEP[eval]: Query id=34: reranking 100 candidates ...
# STEP[eval]: Query id=34: got 100 results after rerank
# STEP[eval]: Query id=42: retrieving candidates ...
# STEP[eval]: Query id=42: reranking 100 candidates ...
# STEP[eval]: Query id=42: got 100 results after rerank
# STEP[eval]: Query id=56: retrieving candidates ...
# STEP[eval]: Query id=34: reranking 100 candidates ...
# STEP[eval]: Query id=34: got 100 results after rerank
# STEP[eval]: Query id=42: retrieving candidates ...
# STEP[eval]: Query id=42: reranking 100 candidates ...
# STEP[eval]: Query id=42: got 100 results after rerank
# STEP[eval]: Query id=56: retrieving candidates ...
# STEP[eval]: Query id=56: reranking 100 candidates ...
# STEP[eval]: Query id=56: got 100 results after rerank
# STEP[eval]: Query id=68: retrieving candidates ...
# STEP[eval]: Query id=68: reranking 100 candidates ...
# STEP[eval]: Query id=68: got 100 results after rerank
# STEP[eval]: Query id=89: retrieving candidates ...
# STEP[eval]: Query id=56: reranking 100 candidates ...
# STEP[eval]: Query id=56: got 100 results after rerank
# STEP[eval]: Query id=68: retrieving candidates ...
# STEP[eval]: Query id=68: reranking 100 candidates ...
# STEP[eval]: Query id=68: got 100 results after rerank
# STEP[eval]: Query id=89: retrieving candidates ...
# STEP[eval]: Query id=89: reranking 100 candidates ...
# STEP[eval]: Query id=89: got 100 results after rerank
# STEP[eval]: Query id=90: retrieving candidates ...
# STEP[eval]: Query id=89: reranking 100 candidates ...
# STEP[eval]: Query id=89: got 100 results after rerank
# STEP[eval]: Query id=90: retrieving candidates ...
# STEP[eval]: Query id=90: reranking 100 candidates ...
# STEP[eval]: Query id=90: got 100 results after rerank
# STEP[eval]: Query id=94: retrieving candidates ...
# STEP[eval]: Query id=94: reranking 100 candidates ...
# STEP[eval]: Query id=94: got 100 results after rerank
# STEP[eval]: Query id=98: retrieving candidates ...
# STEP[eval]: Query id=90: reranking 100 candidates ...
# STEP[eval]: Query id=90: got 100 results after rerank
# STEP[eval]: Query id=94: retrieving candidates ...
# STEP[eval]: Query id=94: reranking 100 candidates ...
# STEP[eval]: Query id=94: got 100 results after rerank
# STEP[eval]: Query id=98: retrieving candidates ...
# STEP[eval]: Query id=98: reranking 100 candidates ...
# STEP[eval]: Query id=98: got 100 results after rerank
# STEP[eval]: Query id=104: retrieving candidates ...
# STEP[eval]: Query id=104: reranking 100 candidates ...
# STEP[eval]: Query id=104: got 100 results after rerank
# STEP[eval]: Query id=106: retrieving candidates ...
# STEP[eval]: Query id=98: reranking 100 candidates ...
# STEP[eval]: Query id=98: got 100 results after rerank
# STEP[eval]: Query id=104: retrieving candidates ...
# STEP[eval]: Query id=104: reranking 100 candidates ...
# STEP[eval]: Query id=104: got 100 results after rerank
# STEP[eval]: Query id=106: retrieving candidates ...
# STEP[eval]: Query id=106: reranking 100 candidates ...
# STEP[eval]: Query id=106: got 100 results after rerank
# STEP[eval]: Query id=109: retrieving candidates ...
# STEP[eval]: Query id=106: reranking 100 candidates ...
# STEP[eval]: Query id=106: got 100 results after rerank
# STEP[eval]: Query id=109: retrieving candidates ...
# STEP[eval]: Query id=109: reranking 100 candidates ...
# STEP[eval]: Query id=109: got 100 results after rerank
# STEP[eval]: Query id=475: retrieving candidates ...
# STEP[eval]: Query id=475: reranking 100 candidates ...
# STEP[eval]: Query id=475: got 100 results after rerank
# STEP[eval]: Query id=503: retrieving candidates ...
# STEP[eval]: Query id=109: reranking 100 candidates ...
# STEP[eval]: Query id=109: got 100 results after rerank
# STEP[eval]: Query id=475: retrieving candidates ...
# STEP[eval]: Query id=475: reranking 100 candidates ...
# STEP[eval]: Query id=475: got 100 results after rerank
# STEP[eval]: Query id=503: retrieving candidates ...
# STEP[eval]: Query id=503: reranking 100 candidates ...
# STEP[eval]: Query id=503: got 100 results after rerank
# STEP[eval]: Query id=504: retrieving candidates ...
# STEP[eval]: Query id=504: reranking 100 candidates ...
# STEP[eval]: Query id=504: got 100 results after rerank
# STEP[eval]: Query id=515: retrieving candidates ...
# STEP[eval]: Query id=503: reranking 100 candidates ...
# STEP[eval]: Query id=503: got 100 results after rerank
# STEP[eval]: Query id=504: retrieving candidates ...
# STEP[eval]: Query id=504: reranking 100 candidates ...
# STEP[eval]: Query id=504: got 100 results after rerank
# STEP[eval]: Query id=515: retrieving candidates ...
# STEP[eval]: Query id=515: reranking 100 candidates ...
# STEP[eval]: Query id=515: got 100 results after rerank
# STEP[eval]: Query id=529: retrieving candidates ...
# STEP[eval]: Query id=529: reranking 100 candidates ...
# STEP[eval]: Query id=529: got 100 results after rerank
# STEP[eval]: Query id=547: retrieving candidates ...
# STEP[eval]: Query id=515: reranking 100 candidates ...
# STEP[eval]: Query id=515: got 100 results after rerank
# STEP[eval]: Query id=529: retrieving candidates ...
# STEP[eval]: Query id=529: reranking 100 candidates ...
# STEP[eval]: Query id=529: got 100 results after rerank
# STEP[eval]: Query id=547: retrieving candidates ...
# STEP[eval]: Query id=547: reranking 100 candidates ...
# STEP[eval]: Query id=547: got 100 results after rerank
# STEP[eval]: Query id=549: retrieving candidates ...
# STEP[eval]: Query id=549: reranking 100 candidates ...
# STEP[eval]: Query id=549: got 100 results after rerank
# STEP[eval]: Query id=559: retrieving candidates ...
# STEP[eval]: Query id=547: reranking 100 candidates ...
# STEP[eval]: Query id=547: got 100 results after rerank
# STEP[eval]: Query id=549: retrieving candidates ...
# STEP[eval]: Query id=549: reranking 100 candidates ...
# STEP[eval]: Query id=549: got 100 results after rerank
# STEP[eval]: Query id=559: retrieving candidates ...
# STEP[eval]: Query id=559: reranking 100 candidates ...
# STEP[eval]: Query id=559: got 100 results after rerank
# STEP[eval]: Query id=570: retrieving candidates ...
# STEP[eval]: Query id=570: reranking 100 candidates ...
# STEP[eval]: Query id=570: got 100 results after rerank
# STEP[eval]: Query id=585: retrieving candidates ...
# STEP[eval]: Query id=559: reranking 100 candidates ...
# STEP[eval]: Query id=559: got 100 results after rerank
# STEP[eval]: Query id=570: retrieving candidates ...
# STEP[eval]: Query id=570: reranking 100 candidates ...
# STEP[eval]: Query id=570: got 100 results after rerank
# STEP[eval]: Query id=585: retrieving candidates ...
# STEP[eval]: Query id=585: reranking 100 candidates ...
# STEP[eval]: Query id=585: got 100 results after rerank
# STEP[eval]: Query id=588: retrieving candidates ...
# STEP[eval]: Query id=585: reranking 100 candidates ...
# STEP[eval]: Query id=585: got 100 results after rerank
# STEP[eval]: Query id=588: retrieving candidates ...
# STEP[eval]: Query id=588: reranking 100 candidates ...
# STEP[eval]: Query id=588: got 100 results after rerank
# STEP[eval]: Query id=594: retrieving candidates ...
# STEP[eval]: Query id=594: reranking 100 candidates ...
# STEP[eval]: Query id=594: got 100 results after rerank
# STEP[eval]: Query id=603: retrieving candidates ...
# STEP[eval]: Query id=588: reranking 100 candidates ...
# STEP[eval]: Query id=588: got 100 results after rerank
# STEP[eval]: Query id=594: retrieving candidates ...
# STEP[eval]: Query id=594: reranking 100 candidates ...
# STEP[eval]: Query id=594: got 100 results after rerank
# STEP[eval]: Query id=603: retrieving candidates ...
# STEP[eval]: Query id=603: reranking 100 candidates ...
# STEP[eval]: Query id=603: got 100 results after rerank
# STEP[eval]: Query id=604: retrieving candidates ...
# STEP[eval]: Query id=604: reranking 100 candidates ...
# STEP[eval]: Query id=604: got 100 results after rerank
# STEP[eval]: Query id=620: retrieving candidates ...
# STEP[eval]: Query id=603: reranking 100 candidates ...
# STEP[eval]: Query id=603: got 100 results after rerank
# STEP[eval]: Query id=604: retrieving candidates ...
# STEP[eval]: Query id=604: reranking 100 candidates ...
# STEP[eval]: Query id=604: got 100 results after rerank
# STEP[eval]: Query id=620: retrieving candidates ...
# STEP[eval]: Query id=620: reranking 100 candidates ...
# STEP[eval]: Query id=620: got 100 results after rerank
# STEP[eval]: Query id=622: retrieving candidates ...
# STEP[eval]: Query id=622: reranking 100 candidates ...
# STEP[eval]: Query id=622: got 100 results after rerank
# STEP[eval]: Query id=659: retrieving candidates ...
# STEP[eval]: Query id=620: reranking 100 candidates ...
# STEP[eval]: Query id=620: got 100 results after rerank
# STEP[eval]: Query id=622: retrieving candidates ...
# STEP[eval]: Query id=622: reranking 100 candidates ...
# STEP[eval]: Query id=622: got 100 results after rerank
# STEP[eval]: Query id=659: retrieving candidates ...
# STEP[eval]: Query id=659: reranking 100 candidates ...
# STEP[eval]: Query id=659: got 100 results after rerank
# STEP[eval]: Query id=672: retrieving candidates ...
# STEP[eval]: Query id=672: reranking 100 candidates ...
# STEP[eval]: Query id=672: got 100 results after rerank
# STEP[eval]: Query id=684: retrieving candidates ...
# STEP[eval]: Query id=659: reranking 100 candidates ...
# STEP[eval]: Query id=659: got 100 results after rerank
# STEP[eval]: Query id=672: retrieving candidates ...
# STEP[eval]: Query id=672: reranking 100 candidates ...
# STEP[eval]: Query id=672: got 100 results after rerank
# STEP[eval]: Query id=684: retrieving candidates ...
# STEP[eval]: Query id=684: reranking 100 candidates ...
# STEP[eval]: Query id=684: got 100 results after rerank
# STEP[eval]: Query id=687: retrieving candidates ...
# STEP[eval]: Query id=684: reranking 100 candidates ...
# STEP[eval]: Query id=684: got 100 results after rerank
# STEP[eval]: Query id=687: retrieving candidates ...
# STEP[eval]: Query id=687: reranking 100 candidates ...
# STEP[eval]: Query id=687: got 100 results after rerank
# STEP[eval]: Query id=689: retrieving candidates ...
# STEP[eval]: Query id=689: reranking 100 candidates ...
# STEP[eval]: Query id=689: got 100 results after rerank
# STEP[eval]: Query id=691: retrieving candidates ...
# STEP[eval]: Query id=687: reranking 100 candidates ...
# STEP[eval]: Query id=687: got 100 results after rerank
# STEP[eval]: Query id=689: retrieving candidates ...
# STEP[eval]: Query id=689: reranking 100 candidates ...
# STEP[eval]: Query id=689: got 100 results after rerank
# STEP[eval]: Query id=691: retrieving candidates ...
# STEP[eval]: Query id=691: reranking 100 candidates ...
# STEP[eval]: Query id=691: got 100 results after rerank
# STEP[eval]: Query id=699: retrieving candidates ...
# STEP[eval]: Query id=699: reranking 100 candidates ...
# STEP[eval]: Query id=699: got 100 results after rerank
# STEP[eval]: Query id=701: retrieving candidates ...
# STEP[eval]: Query id=691: reranking 100 candidates ...
# STEP[eval]: Query id=691: got 100 results after rerank
# STEP[eval]: Query id=699: retrieving candidates ...
# STEP[eval]: Query id=699: reranking 100 candidates ...
# STEP[eval]: Query id=699: got 100 results after rerank
# STEP[eval]: Query id=701: retrieving candidates ...
# STEP[eval]: Query id=701: reranking 100 candidates ...
# STEP[eval]: Query id=701: got 100 results after rerank
# STEP[eval]: Query id=715: retrieving candidates ...
# STEP[eval]: Query id=701: reranking 100 candidates ...
# STEP[eval]: Query id=701: got 100 results after rerank
# STEP[eval]: Query id=715: retrieving candidates ...
# STEP[eval]: Query id=715: reranking 100 candidates ...
# STEP[eval]: Query id=715: got 100 results after rerank
# STEP[eval]: Query id=721: retrieving candidates ...
# STEP[eval]: Query id=715: reranking 100 candidates ...
# STEP[eval]: Query id=715: got 100 results after rerank
# STEP[eval]: Query id=721: retrieving candidates ...
# STEP[eval]: Query id=721: reranking 100 candidates ...
# STEP[eval]: Query id=721: got 100 results after rerank
# STEP[eval]: Query id=744: retrieving candidates ...
# STEP[eval]: Query id=744: reranking 100 candidates ...
# STEP[eval]: Query id=744: got 100 results after rerank
# STEP[eval]: Query id=750: retrieving candidates ...
# STEP[eval]: Query id=721: reranking 100 candidates ...
# STEP[eval]: Query id=721: got 100 results after rerank
# STEP[eval]: Query id=744: retrieving candidates ...
# STEP[eval]: Query id=744: reranking 100 candidates ...
# STEP[eval]: Query id=744: got 100 results after rerank
# STEP[eval]: Query id=750: retrieving candidates ...
# STEP[eval]: Query id=750: reranking 100 candidates ...
# STEP[eval]: Query id=750: got 100 results after rerank
# STEP[eval]: Query id=753: retrieving candidates ...
# STEP[eval]: Query id=753: reranking 100 candidates ...
# STEP[eval]: Query id=753: got 100 results after rerank
# STEP[eval]: Query id=766: retrieving candidates ...
# STEP[eval]: Query id=750: reranking 100 candidates ...
# STEP[eval]: Query id=750: got 100 results after rerank
# STEP[eval]: Query id=753: retrieving candidates ...
# STEP[eval]: Query id=753: reranking 100 candidates ...
# STEP[eval]: Query id=753: got 100 results after rerank
# STEP[eval]: Query id=766: retrieving candidates ...
# STEP[eval]: Query id=766: reranking 100 candidates ...
# STEP[eval]: Query id=766: got 100 results after rerank
# STEP[eval]: Query id=776: retrieving candidates ...
# STEP[eval]: Query id=776: reranking 100 candidates ...
# STEP[eval]: Query id=776: got 100 results after rerank
# STEP[eval]: Query id=810: retrieving candidates ...
# STEP[eval]: Query id=766: reranking 100 candidates ...
# STEP[eval]: Query id=766: got 100 results after rerank
# STEP[eval]: Query id=776: retrieving candidates ...
# STEP[eval]: Query id=776: reranking 100 candidates ...
# STEP[eval]: Query id=776: got 100 results after rerank
# STEP[eval]: Query id=810: retrieving candidates ...
# STEP[eval]: Query id=810: reranking 100 candidates ...
# STEP[eval]: Query id=810: got 100 results after rerank
# STEP[eval]: Query id=813: retrieving candidates ...
# STEP[eval]: Query id=810: reranking 100 candidates ...
# STEP[eval]: Query id=810: got 100 results after rerank
# STEP[eval]: Query id=813: retrieving candidates ...
# STEP[eval]: Query id=813: reranking 100 candidates ...
# STEP[eval]: Query id=813: got 100 results after rerank
# STEP[eval]: Query id=849: retrieving candidates ...
# STEP[eval]: Query id=849: reranking 100 candidates ...
# STEP[eval]: Query id=849: got 100 results after rerank
# STEP[eval]: Query id=852: retrieving candidates ...
# STEP[eval]: Query id=813: reranking 100 candidates ...
# STEP[eval]: Query id=813: got 100 results after rerank
# STEP[eval]: Query id=849: retrieving candidates ...
# STEP[eval]: Query id=849: reranking 100 candidates ...
# STEP[eval]: Query id=849: got 100 results after rerank
# STEP[eval]: Query id=852: retrieving candidates ...
# STEP[eval]: Query id=852: reranking 100 candidates ...
# STEP[eval]: Query id=852: got 100 results after rerank
# STEP[eval]: Query id=853: retrieving candidates ...
# STEP[eval]: Query id=853: reranking 100 candidates ...
# STEP[eval]: Query id=853: got 100 results after rerank
# STEP[eval]: Query id=858: retrieving candidates ...
# STEP[eval]: Query id=852: reranking 100 candidates ...
# STEP[eval]: Query id=852: got 100 results after rerank
# STEP[eval]: Query id=853: retrieving candidates ...
# STEP[eval]: Query id=853: reranking 100 candidates ...
# STEP[eval]: Query id=853: got 100 results after rerank
# STEP[eval]: Query id=858: retrieving candidates ...
# STEP[eval]: Query id=858: reranking 100 candidates ...
# STEP[eval]: Query id=858: got 100 results after rerank
# STEP[eval]: Query id=859: retrieving candidates ...
# STEP[eval]: Query id=859: reranking 100 candidates ...
# STEP[eval]: Query id=859: got 100 results after rerank
# STEP[eval]: Query id=864: retrieving candidates ...
# STEP[eval]: Query id=858: reranking 100 candidates ...
# STEP[eval]: Query id=858: got 100 results after rerank
# STEP[eval]: Query id=859: retrieving candidates ...
# STEP[eval]: Query id=859: reranking 100 candidates ...
# STEP[eval]: Query id=859: got 100 results after rerank
# STEP[eval]: Query id=864: retrieving candidates ...
# STEP[eval]: Query id=864: reranking 100 candidates ...
# STEP[eval]: Query id=864: got 100 results after rerank
# STEP[eval]: Query id=879: retrieving candidates ...
# STEP[eval]: Query id=879: reranking 100 candidates ...
# STEP[eval]: Query id=879: got 100 results after rerank
# STEP[eval]: Query id=885: retrieving candidates ...
# STEP[eval]: Query id=864: reranking 100 candidates ...
# STEP[eval]: Query id=864: got 100 results after rerank
# STEP[eval]: Query id=879: retrieving candidates ...
# STEP[eval]: Query id=879: reranking 100 candidates ...
# STEP[eval]: Query id=879: got 100 results after rerank
# STEP[eval]: Query id=885: retrieving candidates ...
# STEP[eval]: Query id=885: reranking 100 candidates ...
# STEP[eval]: Query id=885: got 100 results after rerank
# STEP[eval]: Query id=895: retrieving candidates ...
# STEP[eval]: Query id=885: reranking 100 candidates ...
# STEP[eval]: Query id=885: got 100 results after rerank
# STEP[eval]: Query id=895: retrieving candidates ...
# STEP[eval]: Query id=895: reranking 100 candidates ...
# STEP[eval]: Query id=895: got 100 results after rerank
# STEP[eval]: Query id=904: retrieving candidates ...
# STEP[eval]: Query id=904: reranking 100 candidates ...
# STEP[eval]: Query id=904: got 100 results after rerank
# STEP[eval]: Query id=928: retrieving candidates ...
# STEP[eval]: Query id=895: reranking 100 candidates ...
# STEP[eval]: Query id=895: got 100 results after rerank
# STEP[eval]: Query id=904: retrieving candidates ...
# STEP[eval]: Query id=904: reranking 100 candidates ...
# STEP[eval]: Query id=904: got 100 results after rerank
# STEP[eval]: Query id=928: retrieving candidates ...
# STEP[eval]: Query id=928: reranking 100 candidates ...
# STEP[eval]: Query id=928: got 100 results after rerank
# STEP[eval]: Query id=929: retrieving candidates ...
# STEP[eval]: Query id=929: reranking 100 candidates ...
# STEP[eval]: Query id=929: got 100 results after rerank
# STEP[eval]: Query id=932: retrieving candidates ...
# STEP[eval]: Query id=928: reranking 100 candidates ...
# STEP[eval]: Query id=928: got 100 results after rerank
# STEP[eval]: Query id=929: retrieving candidates ...
# STEP[eval]: Query id=929: reranking 100 candidates ...
# STEP[eval]: Query id=929: got 100 results after rerank
# STEP[eval]: Query id=932: retrieving candidates ...
# STEP[eval]: Query id=932: reranking 100 candidates ...
# STEP[eval]: Query id=932: got 100 results after rerank
# STEP[eval]: Query id=939: retrieving candidates ...
# STEP[eval]: Query id=939: reranking 100 candidates ...
# STEP[eval]: Query id=939: got 100 results after rerank
# STEP[eval]: Query id=945: retrieving candidates ...
# STEP[eval]: Query id=932: reranking 100 candidates ...
# STEP[eval]: Query id=932: got 100 results after rerank
# STEP[eval]: Query id=939: retrieving candidates ...
# STEP[eval]: Query id=939: reranking 100 candidates ...
# STEP[eval]: Query id=939: got 100 results after rerank
# STEP[eval]: Query id=945: retrieving candidates ...
# STEP[eval]: Query id=945: reranking 100 candidates ...
# STEP[eval]: Query id=945: got 100 results after rerank
# STEP[eval]: Query id=957: retrieving candidates ...
# STEP[eval]: Query id=957: reranking 100 candidates ...
# STEP[eval]: Query id=957: got 100 results after rerank
# STEP[eval]: Query id=988: retrieving candidates ...
# STEP[eval]: Query id=945: reranking 100 candidates ...
# STEP[eval]: Query id=945: got 100 results after rerank
# STEP[eval]: Query id=957: retrieving candidates ...
# STEP[eval]: Query id=957: reranking 100 candidates ...
# STEP[eval]: Query id=957: got 100 results after rerank
# STEP[eval]: Query id=988: retrieving candidates ...
# STEP[eval]: Query id=988: reranking 100 candidates ...
# STEP[eval]: Query id=988: got 100 results after rerank
# STEP[eval]: Query id=1074: retrieving candidates ...
# STEP[eval]: Query id=988: reranking 100 candidates ...
# STEP[eval]: Query id=988: got 100 results after rerank
# STEP[eval]: Query id=1074: retrieving candidates ...
# STEP[eval]: Query id=1074: reranking 100 candidates ...
# STEP[eval]: Query id=1074: got 100 results after rerank
# STEP[eval]: Query id=1085: retrieving candidates ...
# STEP[eval]: Query id=1085: reranking 100 candidates ...
# STEP[eval]: Query id=1085: got 100 results after rerank
# STEP[eval]: Query id=1090: retrieving candidates ...
# STEP[eval]: Query id=1074: reranking 100 candidates ...
# STEP[eval]: Query id=1074: got 100 results after rerank
# STEP[eval]: Query id=1085: retrieving candidates ...
# STEP[eval]: Query id=1085: reranking 100 candidates ...
# STEP[eval]: Query id=1085: got 100 results after rerank
# STEP[eval]: Query id=1090: retrieving candidates ...
# STEP[eval]: Query id=1090: reranking 100 candidates ...
# STEP[eval]: Query id=1090: got 100 results after rerank
# STEP[eval]: Query id=1150: retrieving candidates ...
# STEP[eval]: Query id=1150: reranking 100 candidates ...
# STEP[eval]: Query id=1150: got 100 results after rerank
# STEP[eval]: Query id=1157: retrieving candidates ...
# STEP[eval]: Query id=1090: reranking 100 candidates ...
# STEP[eval]: Query id=1090: got 100 results after rerank
# STEP[eval]: Query id=1150: retrieving candidates ...
# STEP[eval]: Query id=1150: reranking 100 candidates ...
# STEP[eval]: Query id=1150: got 100 results after rerank
# STEP[eval]: Query id=1157: retrieving candidates ...
# STEP[eval]: Query id=1157: reranking 100 candidates ...
# STEP[eval]: Query id=1157: got 100 results after rerank
# STEP[eval]: Query id=1159: retrieving candidates ...
# STEP[eval]: Query id=1159: reranking 100 candidates ...
# STEP[eval]: Query id=1159: got 100 results after rerank
# STEP[eval]: Query id=1198: retrieving candidates ...
# STEP[eval]: Query id=1157: reranking 100 candidates ...
# STEP[eval]: Query id=1157: got 100 results after rerank
# STEP[eval]: Query id=1159: retrieving candidates ...
# STEP[eval]: Query id=1159: reranking 100 candidates ...
# STEP[eval]: Query id=1159: got 100 results after rerank
# STEP[eval]: Query id=1198: retrieving candidates ...
# STEP[eval]: Query id=1198: reranking 100 candidates ...
# STEP[eval]: Query id=1198: got 100 results after rerank
# STEP[eval]: Query id=1230: retrieving candidates ...
# STEP[eval]: Query id=1230: reranking 100 candidates ...
# STEP[eval]: Query id=1230: got 100 results after rerank
# STEP[eval]: Query id=1281: retrieving candidates ...
# STEP[eval]: Query id=1198: reranking 100 candidates ...
# STEP[eval]: Query id=1198: got 100 results after rerank
# STEP[eval]: Query id=1230: retrieving candidates ...
# STEP[eval]: Query id=1230: reranking 100 candidates ...
# STEP[eval]: Query id=1230: got 100 results after rerank
# STEP[eval]: Query id=1281: retrieving candidates ...
# STEP[eval]: Query id=1281: reranking 100 candidates ...
# STEP[eval]: Query id=1281: got 100 results after rerank
# STEP[eval]: Query id=1284: retrieving candidates ...
# STEP[eval]: Query id=1284: reranking 100 candidates ...
# STEP[eval]: Query id=1284: got 100 results after rerank
# STEP[eval]: Query id=1297: retrieving candidates ...
# STEP[eval]: Query id=1281: reranking 100 candidates ...
# STEP[eval]: Query id=1281: got 100 results after rerank
# STEP[eval]: Query id=1284: retrieving candidates ...
# STEP[eval]: Query id=1284: reranking 100 candidates ...
# STEP[eval]: Query id=1284: got 100 results after rerank
# STEP[eval]: Query id=1297: retrieving candidates ...
# STEP[eval]: Query id=1297: reranking 100 candidates ...
# STEP[eval]: Query id=1297: got 100 results after rerank
# STEP[eval]: Query id=1306: retrieving candidates ...
# STEP[eval]: Query id=1306: reranking 100 candidates ...
# STEP[eval]: Query id=1306: got 100 results after rerank
# STEP[eval]: Query id=1309: retrieving candidates ...
# STEP[eval]: Query id=1297: reranking 100 candidates ...
# STEP[eval]: Query id=1297: got 100 results after rerank
# STEP[eval]: Query id=1306: retrieving candidates ...
# STEP[eval]: Query id=1306: reranking 100 candidates ...
# STEP[eval]: Query id=1306: got 100 results after rerank
# STEP[eval]: Query id=1309: retrieving candidates ...
# STEP[eval]: Query id=1309: reranking 100 candidates ...
# STEP[eval]: Query id=1309: got 100 results after rerank
# STEP[eval]: Query id=1310: retrieving candidates ...
# STEP[eval]: Query id=1310: reranking 100 candidates ...
# STEP[eval]: Query id=1310: got 100 results after rerank
# STEP[eval]: Query id=1321: retrieving candidates ...
# STEP[eval]: Query id=1309: reranking 100 candidates ...
# STEP[eval]: Query id=1309: got 100 results after rerank
# STEP[eval]: Query id=1310: retrieving candidates ...
# STEP[eval]: Query id=1310: reranking 100 candidates ...
# STEP[eval]: Query id=1310: got 100 results after rerank
# STEP[eval]: Query id=1321: retrieving candidates ...
# STEP[eval]: Query id=1321: reranking 100 candidates ...
# STEP[eval]: Query id=1321: got 100 results after rerank
# STEP[eval]: Query id=1322: retrieving candidates ...
# STEP[eval]: Query id=1322: reranking 100 candidates ...
# STEP[eval]: Query id=1322: got 100 results after rerank
# STEP[eval]: Query id=1391: retrieving candidates ...
# STEP[eval]: Query id=1321: reranking 100 candidates ...
# STEP[eval]: Query id=1321: got 100 results after rerank
# STEP[eval]: Query id=1322: retrieving candidates ...
# STEP[eval]: Query id=1322: reranking 100 candidates ...
# STEP[eval]: Query id=1322: got 100 results after rerank
# STEP[eval]: Query id=1391: retrieving candidates ...
# STEP[eval]: Query id=1391: reranking 100 candidates ...
# STEP[eval]: Query id=1391: got 100 results after rerank
# STEP[eval]: Query id=1393: retrieving candidates ...
# STEP[eval]: Query id=1393: reranking 100 candidates ...
# STEP[eval]: Query id=1393: got 100 results after rerank
# STEP[eval]: Query id=1415: retrieving candidates ...
# STEP[eval]: Query id=1391: reranking 100 candidates ...
# STEP[eval]: Query id=1391: got 100 results after rerank
# STEP[eval]: Query id=1393: retrieving candidates ...
# STEP[eval]: Query id=1393: reranking 100 candidates ...
# STEP[eval]: Query id=1393: got 100 results after rerank
# STEP[eval]: Query id=1415: retrieving candidates ...
# STEP[eval]: Query id=1415: reranking 100 candidates ...
# STEP[eval]: Query id=1415: got 100 results after rerank
# STEP[eval]: Query id=1416: retrieving candidates ...
# STEP[eval]: Query id=1416: reranking 100 candidates ...
# STEP[eval]: Query id=1416: got 100 results after rerank
# STEP[eval]: Query id=1441: retrieving candidates ...
# STEP[eval]: Query id=1415: reranking 100 candidates ...
# STEP[eval]: Query id=1415: got 100 results after rerank
# STEP[eval]: Query id=1416: retrieving candidates ...
# STEP[eval]: Query id=1416: reranking 100 candidates ...
# STEP[eval]: Query id=1416: got 100 results after rerank
# STEP[eval]: Query id=1441: retrieving candidates ...
# STEP[eval]: Query id=1441: reranking 100 candidates ...
# STEP[eval]: Query id=1441: got 100 results after rerank
# STEP[eval]: Query id=1451: retrieving candidates ...
# STEP[eval]: Query id=1451: reranking 100 candidates ...
# STEP[eval]: Query id=1451: got 100 results after rerank
# STEP[eval]: Query id=1469: retrieving candidates ...
# STEP[eval]: Query id=1441: reranking 100 candidates ...
# STEP[eval]: Query id=1441: got 100 results after rerank
# STEP[eval]: Query id=1451: retrieving candidates ...
# STEP[eval]: Query id=1451: reranking 100 candidates ...
# STEP[eval]: Query id=1451: got 100 results after rerank
# STEP[eval]: Query id=1469: retrieving candidates ...
# STEP[eval]: Query id=1469: reranking 100 candidates ...
# STEP[eval]: Query id=1469: got 100 results after rerank
# STEP[eval]: Query id=1530: retrieving candidates ...
# STEP[eval]: Query id=1469: reranking 100 candidates ...
# STEP[eval]: Query id=1469: got 100 results after rerank
# STEP[eval]: Query id=1530: retrieving candidates ...
# STEP[eval]: Query id=1530: reranking 100 candidates ...
# STEP[eval]: Query id=1530: got 100 results after rerank
# STEP[eval]: Query id=1670: retrieving candidates ...
# STEP[eval]: Query id=1670: reranking 100 candidates ...
# STEP[eval]: Query id=1670: got 100 results after rerank
# STEP[eval]: Query id=1676: retrieving candidates ...
# STEP[eval]: Query id=1530: reranking 100 candidates ...
# STEP[eval]: Query id=1530: got 100 results after rerank
# STEP[eval]: Query id=1670: retrieving candidates ...
# STEP[eval]: Query id=1670: reranking 100 candidates ...
# STEP[eval]: Query id=1670: got 100 results after rerank
# STEP[eval]: Query id=1676: retrieving candidates ...
# STEP[eval]: Query id=1676: reranking 100 candidates ...
# STEP[eval]: Query id=1676: got 100 results after rerank
# STEP[eval]: Query id=1736: retrieving candidates ...
# STEP[eval]: Query id=1736: reranking 100 candidates ...
# STEP[eval]: Query id=1736: got 100 results after rerank
# STEP[eval]: Query id=1748: retrieving candidates ...
# STEP[eval]: Query id=1676: reranking 100 candidates ...
# STEP[eval]: Query id=1676: got 100 results after rerank
# STEP[eval]: Query id=1736: retrieving candidates ...
# STEP[eval]: Query id=1736: reranking 100 candidates ...
# STEP[eval]: Query id=1736: got 100 results after rerank
# STEP[eval]: Query id=1748: retrieving candidates ...
# STEP[eval]: Query id=1748: reranking 100 candidates ...
# STEP[eval]: Query id=1748: got 100 results after rerank
# STEP[eval]: Query id=1783: retrieving candidates ...
# STEP[eval]: Query id=1783: reranking 100 candidates ...
# STEP[eval]: Query id=1783: got 100 results after rerank
# STEP[eval]: Query id=1812: retrieving candidates ...
# STEP[eval]: Query id=1748: reranking 100 candidates ...
# STEP[eval]: Query id=1748: got 100 results after rerank
# STEP[eval]: Query id=1783: retrieving candidates ...
# STEP[eval]: Query id=1783: reranking 100 candidates ...
# STEP[eval]: Query id=1783: got 100 results after rerank
# STEP[eval]: Query id=1812: retrieving candidates ...
# STEP[eval]: Query id=1812: reranking 100 candidates ...
# STEP[eval]: Query id=1812: got 100 results after rerank
# STEP[eval]: Query id=1815: retrieving candidates ...
# STEP[eval]: Query id=1815: reranking 100 candidates ...
# STEP[eval]: Query id=1815: got 100 results after rerank
# STEP[eval]: Query id=1819: retrieving candidates ...
# STEP[eval]: Query id=1812: reranking 100 candidates ...
# STEP[eval]: Query id=1812: got 100 results after rerank
# STEP[eval]: Query id=1815: retrieving candidates ...
# STEP[eval]: Query id=1815: reranking 100 candidates ...
# STEP[eval]: Query id=1815: got 100 results after rerank
# STEP[eval]: Query id=1819: retrieving candidates ...
# STEP[eval]: Query id=1819: reranking 100 candidates ...
# STEP[eval]: Query id=1819: got 100 results after rerank
# STEP[eval]: Query id=1824: retrieving candidates ...
# STEP[eval]: Query id=1824: reranking 100 candidates ...
# STEP[eval]: Query id=1824: got 100 results after rerank
# STEP[eval]: Query id=1826: retrieving candidates ...
# STEP[eval]: Query id=1819: reranking 100 candidates ...
# STEP[eval]: Query id=1819: got 100 results after rerank
# STEP[eval]: Query id=1824: retrieving candidates ...
# STEP[eval]: Query id=1824: reranking 100 candidates ...
# STEP[eval]: Query id=1824: got 100 results after rerank
# STEP[eval]: Query id=1826: retrieving candidates ...
# STEP[eval]: Query id=1826: reranking 100 candidates ...
# STEP[eval]: Query id=1826: got 100 results after rerank
# STEP[eval]: Query id=1832: retrieving candidates ...
# STEP[eval]: Query id=1832: reranking 100 candidates ...
# STEP[eval]: Query id=1832: got 100 results after rerank
# STEP[eval]: Query id=1871: retrieving candidates ...
# STEP[eval]: Query id=1826: reranking 100 candidates ...
# STEP[eval]: Query id=1826: got 100 results after rerank
# STEP[eval]: Query id=1832: retrieving candidates ...
# STEP[eval]: Query id=1832: reranking 100 candidates ...
# STEP[eval]: Query id=1832: got 100 results after rerank
# STEP[eval]: Query id=1871: retrieving candidates ...
# STEP[eval]: Query id=1871: reranking 100 candidates ...
# STEP[eval]: Query id=1871: got 100 results after rerank
# STEP[eval]: Query id=1877: retrieving candidates ...
# STEP[eval]: Query id=1877: reranking 100 candidates ...
# STEP[eval]: Query id=1877: got 100 results after rerank
# STEP[eval]: Query id=1889: retrieving candidates ...
# STEP[eval]: Query id=1871: reranking 100 candidates ...
# STEP[eval]: Query id=1871: got 100 results after rerank
# STEP[eval]: Query id=1877: retrieving candidates ...
# STEP[eval]: Query id=1877: reranking 100 candidates ...
# STEP[eval]: Query id=1877: got 100 results after rerank
# STEP[eval]: Query id=1889: retrieving candidates ...
# STEP[eval]: Query id=1889: reranking 100 candidates ...
# STEP[eval]: Query id=1889: got 100 results after rerank
# STEP[eval]: Query id=1915: retrieving candidates ...
# STEP[eval]: Query id=1889: reranking 100 candidates ...
# STEP[eval]: Query id=1889: got 100 results after rerank
# STEP[eval]: Query id=1915: retrieving candidates ...
# STEP[eval]: Query id=1915: reranking 100 candidates ...
# STEP[eval]: Query id=1915: got 100 results after rerank
# STEP[eval]: Query id=1920: retrieving candidates ...
# STEP[eval]: Query id=1920: reranking 100 candidates ...
# STEP[eval]: Query id=1920: got 100 results after rerank
# STEP[eval]: Query id=1933: retrieving candidates ...
# STEP[eval]: Query id=1915: reranking 100 candidates ...
# STEP[eval]: Query id=1915: got 100 results after rerank
# STEP[eval]: Query id=1920: retrieving candidates ...
# STEP[eval]: Query id=1920: reranking 100 candidates ...
# STEP[eval]: Query id=1920: got 100 results after rerank
# STEP[eval]: Query id=1933: retrieving candidates ...
# STEP[eval]: Query id=1933: reranking 100 candidates ...
# STEP[eval]: Query id=1933: got 100 results after rerank
# STEP[eval]: Query id=1948: retrieving candidates ...
# STEP[eval]: Query id=1948: reranking 100 candidates ...
# STEP[eval]: Query id=1948: got 100 results after rerank
# STEP[eval]: Query id=1994: retrieving candidates ...
# STEP[eval]: Query id=1933: reranking 100 candidates ...
# STEP[eval]: Query id=1933: got 100 results after rerank
# STEP[eval]: Query id=1948: retrieving candidates ...
# STEP[eval]: Query id=1948: reranking 100 candidates ...
# STEP[eval]: Query id=1948: got 100 results after rerank
# STEP[eval]: Query id=1994: retrieving candidates ...
# STEP[eval]: Query id=1994: reranking 100 candidates ...
# STEP[eval]: Query id=1994: got 100 results after rerank
# STEP[eval]: Query id=2010: retrieving candidates ...
# STEP[eval]: Query id=2010: reranking 100 candidates ...
# STEP[eval]: Query id=2010: got 100 results after rerank
# STEP[eval]: Query id=2051: retrieving candidates ...
# STEP[eval]: Query id=1994: reranking 100 candidates ...
# STEP[eval]: Query id=1994: got 100 results after rerank
# STEP[eval]: Query id=2010: retrieving candidates ...
# STEP[eval]: Query id=2010: reranking 100 candidates ...
# STEP[eval]: Query id=2010: got 100 results after rerank
# STEP[eval]: Query id=2051: retrieving candidates ...
# STEP[eval]: Query id=2051: reranking 100 candidates ...
# STEP[eval]: Query id=2051: got 100 results after rerank
# STEP[eval]: Query id=2070: retrieving candidates ...
# STEP[eval]: Query id=2070: reranking 100 candidates ...
# STEP[eval]: Query id=2070: got 100 results after rerank
# STEP[eval]: Query id=2075: retrieving candidates ...
# STEP[eval]: Query id=2051: reranking 100 candidates ...
# STEP[eval]: Query id=2051: got 100 results after rerank
# STEP[eval]: Query id=2070: retrieving candidates ...
# STEP[eval]: Query id=2070: reranking 100 candidates ...
# STEP[eval]: Query id=2070: got 100 results after rerank
# STEP[eval]: Query id=2075: retrieving candidates ...
# STEP[eval]: Query id=2075: reranking 100 candidates ...
# STEP[eval]: Query id=2075: got 100 results after rerank
# STEP[eval]: Query id=2076: retrieving candidates ...
# STEP[eval]: Query id=2076: reranking 100 candidates ...
# STEP[eval]: Query id=2076: got 100 results after rerank
# STEP[eval]: Query id=2088: retrieving candidates ...
# STEP[eval]: Query id=2075: reranking 100 candidates ...
# STEP[eval]: Query id=2075: got 100 results after rerank
# STEP[eval]: Query id=2076: retrieving candidates ...
# STEP[eval]: Query id=2076: reranking 100 candidates ...
# STEP[eval]: Query id=2076: got 100 results after rerank
# STEP[eval]: Query id=2088: retrieving candidates ...
# STEP[eval]: Query id=2088: reranking 100 candidates ...
# STEP[eval]: Query id=2088: got 100 results after rerank
# STEP[eval]: Query id=2108: retrieving candidates ...
# STEP[eval]: Query id=2108: reranking 100 candidates ...
# STEP[eval]: Query id=2108: got 100 results after rerank
# STEP[eval]: Query id=2118: retrieving candidates ...
# STEP[eval]: Query id=2088: reranking 100 candidates ...
# STEP[eval]: Query id=2088: got 100 results after rerank
# STEP[eval]: Query id=2108: retrieving candidates ...
# STEP[eval]: Query id=2108: reranking 100 candidates ...
# STEP[eval]: Query id=2108: got 100 results after rerank
# STEP[eval]: Query id=2118: retrieving candidates ...
# STEP[eval]: Query id=2118: reranking 100 candidates ...
# STEP[eval]: Query id=2118: got 100 results after rerank
# STEP[eval]: Query id=2154: retrieving candidates ...
# STEP[eval]: Query id=2154: reranking 100 candidates ...
# STEP[eval]: Query id=2154: got 100 results after rerank
# STEP[eval]: Query id=2181: retrieving candidates ...
# STEP[eval]: Query id=2118: reranking 100 candidates ...
# STEP[eval]: Query id=2118: got 100 results after rerank
# STEP[eval]: Query id=2154: retrieving candidates ...
# STEP[eval]: Query id=2154: reranking 100 candidates ...
# STEP[eval]: Query id=2154: got 100 results after rerank
# STEP[eval]: Query id=2181: retrieving candidates ...
# STEP[eval]: Query id=2181: reranking 100 candidates ...
# STEP[eval]: Query id=2181: got 100 results after rerank
# STEP[eval]: Query id=2183: retrieving candidates ...
# STEP[eval]: Query id=2183: reranking 100 candidates ...
# STEP[eval]: Query id=2183: got 100 results after rerank
# STEP[eval]: Query id=2204: retrieving candidates ...
# STEP[eval]: Query id=2181: reranking 100 candidates ...
# STEP[eval]: Query id=2181: got 100 results after rerank
# STEP[eval]: Query id=2183: retrieving candidates ...
# STEP[eval]: Query id=2183: reranking 100 candidates ...
# STEP[eval]: Query id=2183: got 100 results after rerank
# STEP[eval]: Query id=2204: retrieving candidates ...
# STEP[eval]: Query id=2204: reranking 100 candidates ...
# STEP[eval]: Query id=2204: got 100 results after rerank
# STEP[eval]: Query id=2264: retrieving candidates ...
# STEP[eval]: Query id=2204: reranking 100 candidates ...
# STEP[eval]: Query id=2204: got 100 results after rerank
# STEP[eval]: Query id=2264: retrieving candidates ...
# STEP[eval]: Query id=2264: reranking 100 candidates ...
# STEP[eval]: Query id=2264: got 100 results after rerank
# STEP[eval]: Query id=2296: retrieving candidates ...
# STEP[eval]: Query id=2296: reranking 100 candidates ...
# STEP[eval]: Query id=2296: got 100 results after rerank
# STEP[eval]: Query id=2306: retrieving candidates ...
# STEP[eval]: Query id=2264: reranking 100 candidates ...
# STEP[eval]: Query id=2264: got 100 results after rerank
# STEP[eval]: Query id=2296: retrieving candidates ...
# STEP[eval]: Query id=2296: reranking 100 candidates ...
# STEP[eval]: Query id=2296: got 100 results after rerank
# STEP[eval]: Query id=2306: retrieving candidates ...
# STEP[eval]: Query id=2306: reranking 100 candidates ...
# STEP[eval]: Query id=2306: got 100 results after rerank
# STEP[eval]: Query id=2316: retrieving candidates ...
# STEP[eval]: Query id=2316: reranking 100 candidates ...
# STEP[eval]: Query id=2316: got 100 results after rerank
# STEP[eval]: Query id=2318: retrieving candidates ...
# STEP[eval]: Query id=2306: reranking 100 candidates ...
# STEP[eval]: Query id=2306: got 100 results after rerank
# STEP[eval]: Query id=2316: retrieving candidates ...
# STEP[eval]: Query id=2316: reranking 100 candidates ...
# STEP[eval]: Query id=2316: got 100 results after rerank
# STEP[eval]: Query id=2318: retrieving candidates ...
# STEP[eval]: Query id=2318: reranking 100 candidates ...
# STEP[eval]: Query id=2318: got 100 results after rerank
# STEP[eval]: Query id=2330: retrieving candidates ...
# STEP[eval]: Query id=2318: reranking 100 candidates ...
# STEP[eval]: Query id=2318: got 100 results after rerank
# STEP[eval]: Query id=2330: retrieving candidates ...
# STEP[eval]: Query id=2330: reranking 100 candidates ...
# STEP[eval]: Query id=2330: got 100 results after rerank
# STEP[eval]: Query id=2334: retrieving candidates ...
# STEP[eval]: Query id=2334: reranking 100 candidates ...
# STEP[eval]: Query id=2334: got 100 results after rerank
# STEP[eval]: Query id=2348: retrieving candidates ...
# STEP[eval]: Query id=2330: reranking 100 candidates ...
# STEP[eval]: Query id=2330: got 100 results after rerank
# STEP[eval]: Query id=2334: retrieving candidates ...
# STEP[eval]: Query id=2334: reranking 100 candidates ...
# STEP[eval]: Query id=2334: got 100 results after rerank
# STEP[eval]: Query id=2348: retrieving candidates ...
# STEP[eval]: Query id=2348: reranking 100 candidates ...
# STEP[eval]: Query id=2348: got 100 results after rerank
# STEP[eval]: Query id=2376: retrieving candidates ...
# STEP[eval]: Query id=2376: reranking 100 candidates ...
# STEP[eval]: Query id=2376: got 100 results after rerank
# STEP[eval]: Query id=2383: retrieving candidates ...
# STEP[eval]: Query id=2348: reranking 100 candidates ...
# STEP[eval]: Query id=2348: got 100 results after rerank
# STEP[eval]: Query id=2376: retrieving candidates ...
# STEP[eval]: Query id=2376: reranking 100 candidates ...
# STEP[eval]: Query id=2376: got 100 results after rerank
# STEP[eval]: Query id=2383: retrieving candidates ...
# STEP[eval]: Query id=2383: reranking 100 candidates ...
# STEP[eval]: Query id=2383: got 100 results after rerank
# STEP[eval]: Query id=2384: retrieving candidates ...
# STEP[eval]: Query id=2384: reranking 100 candidates ...
# STEP[eval]: Query id=2384: got 100 results after rerank
# STEP[eval]: Query id=2385: retrieving candidates ...
# STEP[eval]: Query id=2383: reranking 100 candidates ...
# STEP[eval]: Query id=2383: got 100 results after rerank
# STEP[eval]: Query id=2384: retrieving candidates ...
# STEP[eval]: Query id=2384: reranking 100 candidates ...
# STEP[eval]: Query id=2384: got 100 results after rerank
# STEP[eval]: Query id=2385: retrieving candidates ...
# STEP[eval]: Query id=2385: reranking 100 candidates ...
# STEP[eval]: Query id=2385: got 100 results after rerank
# STEP[eval]: Query id=2388: retrieving candidates ...
# STEP[eval]: Query id=2385: reranking 100 candidates ...
# STEP[eval]: Query id=2385: got 100 results after rerank
# STEP[eval]: Query id=2388: retrieving candidates ...
# STEP[eval]: Query id=2388: reranking 100 candidates ...
# STEP[eval]: Query id=2388: got 100 results after rerank
# STEP[eval]: Query id=2395: retrieving candidates ...
# STEP[eval]: Query id=2388: reranking 100 candidates ...
# STEP[eval]: Query id=2388: got 100 results after rerank
# STEP[eval]: Query id=2395: retrieving candidates ...
# STEP[eval]: Query id=2395: reranking 100 candidates ...
# STEP[eval]: Query id=2395: got 100 results after rerank
# STEP[eval]: Query id=2398: retrieving candidates ...
# STEP[eval]: Query id=2398: reranking 100 candidates ...
# STEP[eval]: Query id=2398: got 100 results after rerank
# STEP[eval]: Query id=2399: retrieving candidates ...
# STEP[eval]: Query id=2395: reranking 100 candidates ...
# STEP[eval]: Query id=2395: got 100 results after rerank
# STEP[eval]: Query id=2398: retrieving candidates ...
# STEP[eval]: Query id=2398: reranking 100 candidates ...
# STEP[eval]: Query id=2398: got 100 results after rerank
# STEP[eval]: Query id=2399: retrieving candidates ...
# STEP[eval]: Query id=2399: reranking 100 candidates ...
# STEP[eval]: Query id=2399: got 100 results after rerank
# STEP[eval]: Query id=2400: retrieving candidates ...
# STEP[eval]: Query id=2400: reranking 100 candidates ...
# STEP[eval]: Query id=2400: got 100 results after rerank
# STEP[eval]: Query id=2407: retrieving candidates ...
# STEP[eval]: Query id=2399: reranking 100 candidates ...
# STEP[eval]: Query id=2399: got 100 results after rerank
# STEP[eval]: Query id=2400: retrieving candidates ...
# STEP[eval]: Query id=2400: reranking 100 candidates ...
# STEP[eval]: Query id=2400: got 100 results after rerank
# STEP[eval]: Query id=2407: retrieving candidates ...
# STEP[eval]: Query id=2407: reranking 100 candidates ...
# STEP[eval]: Query id=2407: got 100 results after rerank
# ...
# STEP[eval]: Query id=1670: got 100 results after rerank
# STEP[eval]: Query id=1676: retrieving candidates ...
# STEP[eval]: Query id=1676: reranking 100 candidates ...
# STEP[bi-reranker]: Reranking 100 candidates for query (top_k=100)
# STEP[eval]: Query id=1676: reranking 100 candidates ...
# STEP[bi-reranker]: Reranking 100 candidates for query (top_k=100)
# STEP[bi-reranker]: Prepared passages (num_docs=100)
# STEP[bi-reranker]: Prepared passages (num_docs=100)
# STEP[bi-reranker]: Encoded embeddings -> query_emb.shape=(1, 768), doc_embs.shape=(100, 768)
# STEP[bi-reranker]: Similarity stats -> min=0.0083, max=0.7162, mean=0.3235
# STEP[bi-reranker]: Top-100 doc_ids=['234436', '68524', '487791', '277812', '194899', '408434', '586026', '466213', '77245', '489898', '232544', '382908', '32072', '394871', '220022', '490997', '316074', '452896', '352640', '373043', '58937', '139501', '396708', '477476', '251564', '347723', '599496', '355679', '196920', '452259', '537763', '578196', '427067', '57229', '42665', '454184', '470898', '496309', '327078', '510913', '97852', '357817', '238622', '87102', '109459', '197546', '296408', '525780', '597199', '300418', '375517', '4457', '18647', '505608', '357340', '2369', '196399', '207997', '417295', '103437', '21695', '106684', '31704', '406656', '350555', '72536', '232207', '509218', '65407', '42999', '406042', '575875', '279636', '315598', '417866', '79592', '470826', '233897', '65555', '28633', '105046', '28749', '286592', '282844', '313305', '517033', '185401', '251394', '516108', '549435', '229354', '346134', '15096', '282681', '425405', '142726', '158312', '582010', '426590', '128567'] scores=['0.7162', '0.6926', '0.6574', '0.6330', '0.5738', '0.5667', '0.5526', '0.5510', '0.5500', '0.5427', '0.5413', '0.5365', '0.5259', '0.5113', '0.5049', '0.5021', '0.4727', '0.4707', '0.4645', '0.4597', '0.4497', '0.4492', '0.4466', '0.4412', '0.4382', '0.4305', '0.4284', '0.4201', '0.4105', '0.4084', '0.4040', '0.4013', '0.3963', '0.3941', '0.3920', '0.3882', '0.3847', '0.3839', '0.3755', '0.3664', '0.3639', '0.3629', '0.3564', '0.3553', '0.3465', '0.3374', '0.3362', '0.3359', '0.3301', '0.3181', '0.3171', '0.3124', '0.3114', '0.3114', '0.3013', '0.2974', '0.2935', '0.2902', '0.2858', '0.2836', '0.2793', '0.2674', '0.2660', '0.2590', '0.2510', '0.2502', '0.2498', '0.2448', '0.2433', '0.2369', '0.2364', '0.2317', '0.2261', '0.2259', '0.2231', '0.2150', '0.2100', '0.2071', '0.1997', '0.1972', '0.1889', '0.1847', '0.1612', '0.1578', '0.1500', '0.1417', '0.1183', '0.1056', '0.1044', '0.0905', '0.0863', '0.0840', '0.0805', '0.0722', '0.0622', '0.0470', '0.0464', '0.0299', '0.0263', '0.0083']
# STEP[eval]: Query id=1676: got 100 results after rerank
# STEP[eval]: Query id=1736: retrieving candidates ...
# STEP[bi-reranker]: Encoded embeddings -> query_emb.shape=(1, 768), doc_embs.shape=(100, 768)
# STEP[bi-reranker]: Similarity stats -> min=0.0083, max=0.7162, mean=0.3235
# STEP[bi-reranker]: Top-100 doc_ids=['234436', '68524', '487791', '277812', '194899', '408434', '586026', '466213', '77245', '489898', '232544', '382908', '32072', '394871', '220022', '490997', '316074', '452896', '352640', '373043', '58937', '139501', '396708', '477476', '251564', '347723', '599496', '355679', '196920', '452259', '537763', '578196', '427067', '57229', '42665', '454184', '470898', '496309', '327078', '510913', '97852', '357817', '238622', '87102', '109459', '197546', '296408', '525780', '597199', '300418', '375517', '4457', '18647', '505608', '357340', '2369', '196399', '207997', '417295', '103437', '21695', '106684', '31704', '406656', '350555', '72536', '232207', '509218', '65407', '42999', '406042', '575875', '279636', '315598', '417866', '79592', '470826', '233897', '65555', '28633', '105046', '28749', '286592', '282844', '313305', '517033', '185401', '251394', '516108', '549435', '229354', '346134', '15096', '282681', '425405', '142726', '158312', '582010', '426590', '128567'] scores=['0.7162', '0.6926', '0.6574', '0.6330', '0.5738', '0.5667', '0.5526', '0.5510', '0.5500', '0.5427', '0.5413', '0.5365', '0.5259', '0.5113', '0.5049', '0.5021', '0.4727', '0.4707', '0.4645', '0.4597', '0.4497', '0.4492', '0.4466', '0.4412', '0.4382', '0.4305', '0.4284', '0.4201', '0.4105', '0.4084', '0.4040', '0.4013', '0.3963', '0.3941', '0.3920', '0.3882', '0.3847', '0.3839', '0.3755', '0.3664', '0.3639', '0.3629', '0.3564', '0.3553', '0.3465', '0.3374', '0.3362', '0.3359', '0.3301', '0.3181', '0.3171', '0.3124', '0.3114', '0.3114', '0.3013', '0.2974', '0.2935', '0.2902', '0.2858', '0.2836', '0.2793', '0.2674', '0.2660', '0.2590', '0.2510', '0.2502', '0.2498', '0.2448', '0.2433', '0.2369', '0.2364', '0.2317', '0.2261', '0.2259', '0.2231', '0.2150', '0.2100', '0.2071', '0.1997', '0.1972', '0.1889', '0.1847', '0.1612', '0.1578', '0.1500', '0.1417', '0.1183', '0.1056', '0.1044', '0.0905', '0.0863', '0.0840', '0.0805', '0.0722', '0.0622', '0.0470', '0.0464', '0.0299', '0.0263', '0.0083']
# STEP[eval]: Query id=1676: got 100 results after rerank
# STEP[eval]: Query id=1736: retrieving candidates ...
# STEP[eval]: Query id=1736: reranking 100 candidates ...
# STEP[bi-reranker]: Reranking 100 candidates for query (top_k=100)
# STEP[eval]: Query id=1736: reranking 100 candidates ...
# STEP[bi-reranker]: Reranking 100 candidates for query (top_k=100)
# STEP[bi-reranker]: Prepared passages (num_docs=100)
# STEP[bi-reranker]: Prepared passages (num_docs=100)
# STEP[bi-reranker]: Encoded embeddings -> query_emb.shape=(1, 768), doc_embs.shape=(100, 768)
# STEP[bi-reranker]: Similarity stats -> min=0.0013, max=0.6096, mean=0.2814
# STEP[bi-reranker]: Top-100 doc_ids=['399406', '562896', '277590', '167473', '315275', '354618', '394467', '327366', '188406', '39816', '444748', '426796', '81206', '124452', '444511', '308131', '173929', '386668', '510989', '76248', '345448', '277477', '89622', '50964', '201447', '355592', '581976', '273528', '421743', '421379', '550471', '289483', '467581', '456771', '444590', '321199', '336518', '298776', '425487', '524149', '234030', '11082', '485195', '9814', '325332', '61706', '478230', '264631', '234852', '293363', '171398', '433933', '390598', '36801', '271472', '31509', '15202', '171339', '135571', '77564', '294828', '286843', '397175', '19275', '571801', '292038', '443087', '277855', '375127', '490100', '557870', '346852', '99449', '432077', '241866', '456098', '176284', '402543', '527344', '111466', '89161', '215180', '410243', '551879', '504293', '136040', '313255', '510063', '425352', '513477', '65537', '221978', '85517', '446909', '203475', '319421', '262733', '521070', '498775', '78086'] scores=['0.6096', '0.5620', '0.4494', '0.4378', '0.4226', '0.4156', '0.4114', '0.4102', '0.4081', '0.3970', '0.3891', '0.3837', '0.3787', '0.3714', '0.3663', '0.3628', '0.3625', '0.3555', '0.3499', '0.3488', '0.3483', '0.3448', '0.3402', '0.3313', '0.3293', '0.3289', '0.3268', '0.3242', '0.3238', '0.3216', '0.3215', '0.3210', '0.3200', '0.3171', '0.3134', '0.3126', '0.3125', '0.3099', '0.3076', '0.3023', '0.3010', '0.3003', '0.2962', '0.2925', '0.2901', '0.2881', '0.2868', '0.2854', '0.2852', '0.2820', '0.2819', '0.2793', '0.2773', '0.2728', '0.2719', '0.2700', '0.2678', '0.2677', '0.2668', '0.2645', '0.2640', '0.2577', '0.2567', '0.2518', '0.2503', '0.2497', '0.2496', '0.2485', '0.2416', '0.2399', '0.2346', '0.2330', '0.2324', '0.2322', '0.2292', '0.2290', '0.2260', '0.2190', '0.2189', '0.2086', '0.2052', '0.2037', '0.1935', '0.1895', '0.1882', '0.1849', '0.1789', '0.1779', '0.1778', '0.1725', '0.1725', '0.1630', '0.1628', '0.1586', '0.1582', '0.1424', '0.1244', '0.0827', '0.0552', '0.0013']
# STEP[eval]: Query id=1736: got 100 results after rerank
# STEP[eval]: Query id=1748: retrieving candidates ...
# STEP[bi-reranker]: Encoded embeddings -> query_emb.shape=(1, 768), doc_embs.shape=(100, 768)
# STEP[bi-reranker]: Similarity stats -> min=0.0013, max=0.6096, mean=0.2814
# STEP[bi-reranker]: Top-100 doc_ids=['399406', '562896', '277590', '167473', '315275', '354618', '394467', '327366', '188406', '39816', '444748', '426796', '81206', '124452', '444511', '308131', '173929', '386668', '510989', '76248', '345448', '277477', '89622', '50964', '201447', '355592', '581976', '273528', '421743', '421379', '550471', '289483', '467581', '456771', '444590', '321199', '336518', '298776', '425487', '524149', '234030', '11082', '485195', '9814', '325332', '61706', '478230', '264631', '234852', '293363', '171398', '433933', '390598', '36801', '271472', '31509', '15202', '171339', '135571', '77564', '294828', '286843', '397175', '19275', '571801', '292038', '443087', '277855', '375127', '490100', '557870', '346852', '99449', '432077', '241866', '456098', '176284', '402543', '527344', '111466', '89161', '215180', '410243', '551879', '504293', '136040', '313255', '510063', '425352', '513477', '65537', '221978', '85517', '446909', '203475', '319421', '262733', '521070', '498775', '78086'] scores=['0.6096', '0.5620', '0.4494', '0.4378', '0.4226', '0.4156', '0.4114', '0.4102', '0.4081', '0.3970', '0.3891', '0.3837', '0.3787', '0.3714', '0.3663', '0.3628', '0.3625', '0.3555', '0.3499', '0.3488', '0.3483', '0.3448', '0.3402', '0.3313', '0.3293', '0.3289', '0.3268', '0.3242', '0.3238', '0.3216', '0.3215', '0.3210', '0.3200', '0.3171', '0.3134', '0.3126', '0.3125', '0.3099', '0.3076', '0.3023', '0.3010', '0.3003', '0.2962', '0.2925', '0.2901', '0.2881', '0.2868', '0.2854', '0.2852', '0.2820', '0.2819', '0.2793', '0.2773', '0.2728', '0.2719', '0.2700', '0.2678', '0.2677', '0.2668', '0.2645', '0.2640', '0.2577', '0.2567', '0.2518', '0.2503', '0.2497', '0.2496', '0.2485', '0.2416', '0.2399', '0.2346', '0.2330', '0.2324', '0.2322', '0.2292', '0.2290', '0.2260', '0.2190', '0.2189', '0.2086', '0.2052', '0.2037', '0.1935', '0.1895', '0.1882', '0.1849', '0.1789', '0.1779', '0.1778', '0.1725', '0.1725', '0.1630', '0.1628', '0.1586', '0.1582', '0.1424', '0.1244', '0.0827', '0.0552', '0.0013']
# STEP[eval]: Query id=1736: got 100 results after rerank
# STEP[eval]: Query id=1748: retrieving candidates ...
# STEP[eval]: Query id=1748: reranking 100 candidates ...
# STEP[bi-reranker]: Reranking 100 candidates for query (top_k=100)
# STEP[eval]: Query id=1748: reranking 100 candidates ...
# STEP[bi-reranker]: Reranking 100 candidates for query (top_k=100)
# STEP[bi-reranker]: Prepared passages (num_docs=100)
# STEP[bi-reranker]: Prepared passages (num_docs=100)
# ^C
# Traceback (most recent call last):
#   File "/Users/nkapila6/.local/share/uv/python/cpython-3.11.11-macos-aarch64-none/lib/python3.11/subprocess.py", line 1264, in wait
#     return self._wait(timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nkapila6/.local/share/uv/python/cpython-3.11.11-macos-aarch64-none/lib/python3.11/subprocess.py", line 2053, in _wait
#     (pid, sts) = self._try_wait(0)
#                  ^^^^^^^^^^^^^^^^^
#   File "/Users/nkapila6/.local/share/uv/python/cpython-3.11.11-macos-aarch64-none/lib/python3.11/subprocess.py", line 2011, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/nkapila6/Code/rag-benchmarks/scripts/run_all_combinations.py", line 92, in <module>
#     main()
#   File "/Users/nkapila6/Code/rag-benchmarks/scripts/run_all_combinations.py", line 70, in main
#     subprocess.run(command, check=True)
#   File "/Users/nkapila6/.local/share/uv/python/cpython-3.11.11-macos-aarch64-none/lib/python3.11/subprocess.py", line 550, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nkapila6/.local/share/uv/python/cpython-3.11.11-macos-aarch64-none/lib/python3.11/subprocess.py", line 1201, in communicate
#     self.wait()
#   File "/Users/nkapila6/.local/share/uv/python/cpython-3.11.11-macos-aarch64-none/lib/python3.11/subprocess.py", line 1277, in wait
#     self._wait(timeout=sigint_timeout)
#   File "/Users/nkapila6/.local/share/uv/python/cpython-3.11.11-macos-aarch64-none/lib/python3.11/subprocess.py", line 2047, in _wait
#     time.sleep(delay)
# KeyboardInterrupt
# /Users/nkapila6/.local/share/uv/python/cpython-3.11.11-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
# ^C
# Traceback (most recent call last):
#   File "/Users/nkapila6/.local/share/uv/python/cpython-3.11.11-macos-aarch64-none/lib/python3.11/subprocess.py", line 1264, in wait
#     return self._wait(timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nkapila6/.local/share/uv/python/cpython-3.11.11-macos-aarch64-none/lib/python3.11/subprocess.py", line 2053, in _wait
#     (pid, sts) = self._try_wait(0)
#                  ^^^^^^^^^^^^^^^^^
#   File "/Users/nkapila6/.local/share/uv/python/cpython-3.11.11-macos-aarch64-none/lib/python3.11/subprocess.py", line 2011, in _try_wait
#     (pid, sts) = os.waitpid(self.pid, wait_flags)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/nkapila6/Code/rag-benchmarks/scripts/run_all_combinations.py", line 92, in <module>
#     main()
#   File "/Users/nkapila6/Code/rag-benchmarks/scripts/run_all_combinations.py", line 70, in main
#     subprocess.run(command, check=True)
#   File "/Users/nkapila6/.local/share/uv/python/cpython-3.11.11-macos-aarch64-none/lib/python3.11/subprocess.py", line 550, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nkapila6/.local/share/uv/python/cpython-3.11.11-macos-aarch64-none/lib/python3.11/subprocess.py", line 1201, in communicate
#     self.wait()
#   File "/Users/nkapila6/.local/share/uv/python/cpython-3.11.11-macos-aarch64-none/lib/python3.11/subprocess.py", line 1277, in wait
#     self._wait(timeout=sigint_timeout)
#   File "/Users/nkapila6/.local/share/uv/python/cpython-3.11.11-macos-aarch64-none/lib/python3.11/subprocess.py", line 2047, in _wait
#     time.sleep(delay)
# KeyboardInterrupt
# /Users/nkapila6/.local/share/uv/python/cpython-3.11.11-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
